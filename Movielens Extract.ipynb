# %%
import pandas as pd

# %%
movie_metadata = pd.read_csv('movies_metadata.csv')
ratings = pd.read_csv('ratings.csv')
# Out:
# F:\Anaconda\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3166: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
movie_metadata.sample(10)
# Out:
#        adult belongs_to_collection    budget  \
# 9373   False                   NaN  10000000
# 1044   False                   NaN         0
# 20239  False                   NaN         0
# 18724  False                   NaN  10000000
# 20745  False                   NaN         0
# 14987  False                   NaN         0
# 32772  False                   NaN         0
# 24915  False                   NaN         0
# 43097  False                   NaN         0
# 26823  False                   NaN         0
#
#                                                   genres  \
# 9373                       [{'id': 18, 'name': 'Drama'}]
# 1044                      [{'id': 27, 'name': 'Horror'}]
# 20239  [{'id': 16, 'name': 'Animation'}, {'id': 18, '...
# 18724  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 20745                [{'id': 99, 'name': 'Documentary'}]
# 14987  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# 32772  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 24915  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 43097                [{'id': 99, 'name': 'Documentary'}]
# 26823  [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...
#
#                            homepage      id    imdb_id original_language  \
# 9373                            NaN   12703  tt0330099                en
# 1044                            NaN   16372  tt0055018                en
# 20239                           NaN  100592  tt0239921                cs
# 18724                           NaN   82532  tt1588334                en
# 20745  http://racingdreamsfilm.com/   44671  tt1152840                en
# 14987                           NaN   45035  tt0492835                ko
# 32772                           NaN   32336  tt0084873                ru
# 24915                           NaN   90978  tt0035020                en
# 43097                           NaN  389292  tt4325400                en
# 26823                           NaN  112049  tt0047199                en
#
#                         original_title  \
# 9373                   The Brown Bunny
# 1044                     The Innocents
# 20239                             Ruka
# 18724          Jeff, Who Lives at Home
# 20745                    Racing Dreams
# 14987                            왕의 남자
# 32772                 Вокзал для двоих
# 24915                  The Male Animal
# 43097  Apex: The Story of the Hypercar
# 26823                    Mad About Men
#
#                                                 overview  ... release_date  \
# 9373   Bud Clay races motorcycles in the 250cc Formul...  ...   2004-08-27
# 1044   A young governess for two children becomes con...  ...   1961-12-25
# 20239  A happy little potter is approached by a huge ...  ...   1965-10-26
# 18724  Dispatched from his basement room on an errand...  ...   2011-09-13
# 20745  From go-kart champs, NASCAR winners are bred -...  ...   2010-05-14
# 14987  Set in the late 15th century during the reign ...  ...   2005-12-29
# 32772  Platon Ryabinin, a pianist, is traveling by tr...  ...   1982-06-06
# 24915  The trustees of Midwestern University have for...  ...   1942-04-04
# 43097  Rocket science meets the auto industry as "APE...  ...   2016-03-29
# 26823  Flirtatious mermaid Miranda swaps places with ...  ...   1954-11-16
#
#          revenue runtime                                   spoken_languages  \
# 9373         0.0    93.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 1044         0.0   100.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 20239        0.0    18.0             [{'iso_639_1': 'cs', 'name': 'Český'}]
# 18724  4417580.0    83.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 20745        0.0    93.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 14987        0.0   119.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
# 32772        0.0   141.0           [{'iso_639_1': 'ru', 'name': 'Pусский'}]
# 24915        0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 43097        0.0     0.0                                                 []
# 26823        0.0    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 9373   Released                     I'm not going to be okay, Bud.
# 1044   Released                   Apparitions? Evils? Corruptions?
# 20239  Released                                                NaN
# 18724  Released  The first step to finding your destiny is leav...
# 20745  Released                     Coming of age in a fast world.
# 14987  Released                                                NaN
# 32772  Released                                                NaN
# 24915  Released                                                NaN
# 43097  Released                                                NaN
# 26823  Released                                                NaN
#
#                                  title  video vote_average vote_count
# 9373                   The Brown Bunny  False          5.5       63.0
# 1044                     The Innocents  False          7.5      126.0
# 20239                         The Hand  False          8.2       13.0
# 18724          Jeff, Who Lives at Home  False          6.1      220.0
# 20745                    Racing Dreams  False          6.8        9.0
# 14987               King and the Clown  False          6.9       37.0
# 32772                  Station for Two  False          6.7       16.0
# 24915                  The Male Animal  False          1.0        1.0
# 43097  Apex: The Story of the Hypercar  False          7.0        7.0
# 26823                    Mad About Men  False          5.8        5.0
#
# [10 rows x 24 columns]
